# %% [markdown]
# ## Homework9
# Experiment data:
#
# |$ U(V)$ | 1.5 $V$ | 1.8 $V$ | 2.1 $V$ | 2.18 $V$ | 2.7 $V$ |
# |:--|:--|:--|:--|:--|:--|
# |$I_B (\mu A)$| 178.8|161.8 | 143.7| 138|
# |$I_C (\mu A)$|47727.3|43636.4|39545.45|38454.54|
# |$\beta$ |266.93|269.69|275.19|256.92|
#
# $$ I_C = \frac{5-U}{R_C} (\mu A)$$

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi, array
I_B  = array([178.8,161.8,143.7,138])
I_C = array([47727.3,43636.4,39545.45,38454.54])

plt.figure(figsize=(8, 6))
plt.plot(I_B, I_C, marker='o', linewidth=2, markersize=8, color='b', label='$I_C$ vs $I_B$')

# 添加标题和标签
plt.title('$I_B$ vs $I_C$ Characteristic Curve', fontsize=12)
plt.xlabel('$I_B$ (μA)', fontsize=12)
plt.ylabel('$I_C$ (μA)', fontsize=12)

# 添加网格
plt.grid(True, linestyle='--', alpha=0.6)

# 添加图例
plt.legend(fontsize=11)

# 可选：调整坐标轴范围
plt.xlim(min(I_B)-5, max(I_B)+5)
plt.ylim(min(I_C)-2000, max(I_C)+2000)

# 显示图形
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task C
#
# |$ U_{GS}(V)$ | 3.5 $V$ | 3.6 $V$ | 3.7 $V$ | 3.8 $V$ | 3.9 $V$ | 4.0 $V$ |
# |:--|:--|:--|:--|:--|:--|:--|
# |$I_D ( mA)$| 25.87|42.7 | 56.1| 59.6|59.1|54.7|

# %%
U  = array([3.5,3.6,3.7,3.8,3.9,4.0])
I_D = array([25.87,42.7,56.1, 59.6, 59.1,54.7])

plt.figure(figsize=(8, 6))
plt.plot(U, I_D, marker='o', linewidth=2, markersize=8, color='b', label='U vs $I_D$')

# 添加标题和标签
plt.title('$U_{GS}$ vs $I_D$ Characteristic Curve', fontsize=12)
plt.xlabel('U (V)', fontsize=12)
plt.ylabel('$I_D $(mA)', fontsize=12)

# 添加网格
plt.grid(True, linestyle='--', alpha=0.6)

# 添加图例
plt.legend(fontsize=11)

# 可选：调整坐标轴范围
# plt.xlim(min(U)-5, max(U)+5)
# plt.ylim(min(I_D)-2, max(I_D)+2)

# 显示图形
plt.tight_layout()
plt.show()
