# %% [markdown]
# # Lab 4 Analysis
#
# ## 1p18 Hz
# The acceleration vs frquency plot shows below,
#
# ![image.png](attachment:image.png)
#
# The spectrum plot and phase differene for $\bold{mass 1}$ are shown below
#
# ![image-2.png](attachment:image-2.png)
#
# two natural frequency are $f_{lower} = 1.20295 Hz ,f_{higher} = 3.60885 Hz$
#
# ![image-3.png](attachment:image-3.png)
#
# corresponding phase difference are
#
# $\phi_1 = -8.65445, \phi_2 = 25.824$
#
# The spectrum plot and phase differene for $\bold{mass 2}$ are shown below
#
# ![image-4.png](attachment:image-4.png)
#
# two natural frequency are $f_{lower} = 1.20295 Hz ,f_{higher} = 3.60885 Hz$
#
# ![image-5.png](attachment:image-5.png)
#
# $\phi_1 = -7.01478, \phi_2 = -151.466$
#
# | Mode | natural frequency $f_n (Hz)$ | Phase difference mass1 $(^{\circ})$ | Phase difference mass2 $(^{\circ})$|
# |:-- |:--  |:-- |:--|
# |$1^{st}$ mode | 1.20295 | -8.65445| -7.01478|
# |$2^{nd}$ mode | 3.60885 | 25.824  | -151.466|
#
#
# ## 3p04 Hz
# The acceleration vs frquency plot shows below,
#
# ![image-6.png](attachment:image-6.png)
#
# The spectrum plot and phase differene for $\bold{mass 1}$ are shown below
#
# ![image-7.png](attachment:image-7.png)
#
# two natural frequency are $f_{lower} = 3.09224 Hz ,f_{higher} = 6.15993 Hz$
#
# ![image-8.png](attachment:image-8.png)
#
# corresponding phase difference are
#
# $\phi_1 = -174.605, \phi_2 = 19.4661$
#
# The spectrum plot and phase differene for $\bold{mass 2}$ are shown below
#
# ![image-9.png](attachment:image-9.png)
#
# same natural frequency
#
# ![image-10.png](attachment:image-10.png)
#
# corresponding phase difference are
#
# $\phi_1 = -6.98351, \phi_2 = -167.821$
#
# | Mode | natural frequency $f_n (Hz)$ | Phase difference mass1 $(^{\circ})$ | Phase difference mass2 $(^{\circ})$|
# |:-- |:--  |:-- |:--|
# |$1^{st}$ mode | 3.09224 | -174.605| -6.98351|
# |$2^{nd}$ mode | 6.15993 | 19.4661  | -167.821|
#
#
# ## 3p98 Hz
# The acceleration vs frquency plot shows below,
#
# ![image-11.png](attachment:image-11.png)
#
# The spectrum plot and phase differene for $\bold{mass 1}$ are shown below
# ![image-13.png](attachment:image-13.png)
#
# two natural frequency are $f_{lower} = 3.9762 Hz ,f_{higher} = 12.0759 Hz$
#
# ![image-15.png](attachment:image-15.png)
#
# corresponding phase difference are
#
# $\phi_1 = 40.0127, \phi_2 = 39.2999$
#
# The spectrum plot and phase differene for $\bold{mass 2}$ are shown below
#
# ![image-14.png](attachment:image-14.png)
#
# same natural frequency
#
# ![image-12.png](attachment:image-12.png)
#
# corresponding phase difference are
#
# $\phi_1 = -150.667 \phi_2 = 39.2999$
#
#
# | Mode | natural frequency $f_n (Hz)$ | Phase difference mass1 $(^{\circ})$ | Phase difference mass2 $(^{\circ})$|
# |:-- |:--  |:-- |:--|
# |$1^{st}$ mode | 3.9762 | 40.0127 | -150.677|
# |$2^{nd}$ mode | 12.0759 | 25.824  | -151.466|

# %%
import numpy
from numpy import array

# %%
f_1 = 1.20295
f_2 = 3.60885

# for mass1
x_11 = 0.307841
x_1b = 0.051671
# for mass 2
x_21 = 0.245729
x_2b = 0.051671
R_1 = x_11/x_1b
R_2 = 1, x_21/x_2b
R_1 = x_11/x_1b
R_2 = x_21/x_2b
print('For 1.18 Hz excitation:')
print("amplitude ratios of X_1/X_b: ")
print(R_1)
print("amplitude ratios of X_2/X_b:: ")
print(R_2)
# Out:
# For 1.18 Hz excitation:
# amplitude ratios of X_1/X_b:
# 5.957713224052176
# amplitude ratios of X_2/X_b::
# 4.75564630063285

# %%
f_1 = 3.09224
f_2 = 6.15993

# for mass1
x_11 = 0.139282
x_1b = 0.301082
# for mass 2
x_21 = 0.0266048
x_2b = 0.301082
R_1 = x_11/x_1b
R_2 = x_21/x_2b
print('For 3.04 Hz excitation:')
print("amplitude ratios of X_1/X_b: ")
print(R_1)
print("amplitude ratios of X_2/X_b:: ")
print(R_2)
# Out:
# For 3.04 Hz excitation:
# amplitude ratios of X_1/X_b:
# 0.4626048717625098
# amplitude ratios of X_2/X_b::
# 0.0883639672913027

# %%
f_1 = 3.9762

# for mass1
x_11 = 0.721391
x_1b = 0.49984
# for mass 2
x_21 = 0.906361
x_2b = 0.49984
R_1 = x_11/x_1b
R_2 = x_21/x_2b
print('For 3.98 Hz excitation:')
print("amplitude ratios of X_1/X_b: ")
print(R_1)
print("amplitude ratios of X_2/X_b:: ")
print(R_2)
# Out:
# For 3.98 Hz excitation:
# amplitude ratios of X_1/X_b:
# 1.443243838028169
# amplitude ratios of X_2/X_b::
# 1.813302256722151
