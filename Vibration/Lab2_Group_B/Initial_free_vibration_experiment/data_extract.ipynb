# %%
from pandas import read_excel
from matplotlib.pyplot import (figure, plot, grid, xlabel, ylabel, show,
  legend, title)
file1 = 'expdata.xlsx'

data1 = read_excel(file1, sheet_name='Sheet1')
print(data1)
# Out:
#              t1    yg1
# 0      0.009966 -0.005
# 1      0.029883 -0.008
# 2      0.049801 -0.005
# 3      0.069718 -0.008
# 4      0.089635 -0.008
# ...         ...    ...
# 2066  41.159285 -0.007
# 2067  41.179203 -0.007
# 2068  41.199120 -0.007
# 2069  41.219037 -0.008
# 2070  41.238955 -0.008
#
# [2071 rows x 2 columns]

# %%
t1  = data1['t1'].values
yg1 = data1['yg1'].values

# %%
# %matplotlib widget
# %matplotlib qt5
# %matplotlib notebook

figure(1)
plot(t1,yg1)
xlabel('time (s)')
ylabel('y acceleration (g)')
grid(True)
title('Free vibration 1DOF system')
show()
